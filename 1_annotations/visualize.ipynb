# %%
import pandas as pd

all = pd.read_csv("../groundtruth/frame/all.csv")
seq = pd.read_csv("../groundtruth/sequence/15fps.csv")
note= pd.read_csv("../noted/5.csv")

all
# Out:
#        id  classe  frame  end_seq  AU01_r  AU02_r  AU04_r  AU05_r  AU06_r  \
# 0       5       1    202      213    1.31    0.46    1.62     0.0    0.11
# 1       5       1    203      213    1.23    0.25    1.60     0.0    0.07
# 2       5       1    204      213    1.15    0.37    1.58     0.0    0.17
# 3       5       1    205      213    0.81    0.25    1.53     0.0    0.29
# 4       5       1    206      213    0.61    0.22    1.51     0.0    0.42
# ...    ..     ...    ...      ...     ...     ...     ...     ...     ...
# 38586  20       4  16096    16100    0.00    0.00    0.34     0.0    1.02
# 38587  20       4  16097    16100    0.00    0.00    0.45     0.0    1.08
# 38588  20       4  16098    16100    0.15    0.00    0.68     0.0    1.09
# 38589  20       4  16099    16100    0.15    0.00    0.76     0.0    1.16
# 38590  20       4  16100    16100    0.15    0.00    0.53     0.0    1.12
#
#        AU07_r  ...  AU10_r  AU12_r  AU14_r  AU15_r  AU17_r  AU20_r  AU23_r  \
# ...

# %%
seq
# Out:
#        id  classe  inizio   fine  min_AU01_r  max_AU01_r  mean_AU01_r  \
# 0       5       2     236    250        0.05        1.43       0.7620
# 1       5       2     237    251        0.11        1.63       0.8673
# 2       5       2     238    252        0.13        1.94       0.9893
# 3       5       2     239    253        0.20        2.61       1.1547
# 4       5       2     240    254        0.29        3.27       1.3593
# ...    ..     ...     ...    ...         ...         ...          ...
# 30569  20       4   16081  16095        0.00        2.77       1.3673
# 30570  20       4   16082  16096        0.00        2.77       1.3180
# 30571  20       4   16083  16097        0.00        2.77       1.2160
# 30572  20       4   16084  16098        0.00        2.77       1.0620
# 30573  20       4   16085  16099        0.00        2.76       0.8873
#
#        stdev_AU01_r  skew_AU01_r  kurt_AU01_r  ...  mean_AU26_r  stdev_AU26_r  \
# ...

# %%
note
# Out:
#      id  classe  inizio   fine
# 0     5       1     202    213
# 1     5       4     223    235
# 2     5       2     236    259
# 3     5       3     270    295
# 4     5       5     298    331
# ..   ..     ...     ...    ...
# 152   5       0   17300  17534
# 153   5       0   17570  17628
# 154   5       0   17660  17785
# 155   5       1   18000  18067
# 156   5       0   18250  18305
#
# [157 rows x 4 columns]
